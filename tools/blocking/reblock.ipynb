# %%
import py_entitymatching as em
import pandas as pd
import os

# %%
######### READING IN TABLES ############

path_a = os.path.join(os.getcwd(), "../../csv/msd_final.csv" )
path_b = os.path.join(os.getcwd(), "../../csv/musicbrainz_final.csv")

A = em.read_csv_metadata(path_a, key='ID')
B = em.read_csv_metadata(path_b, key='ID')

#########################################
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2821: DtypeWarning: Columns (3,4,5,6,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# Metadata file is not present in the given path; proceeding to read the csv file.

# %%
########### FEATURE RULES ##############

## Explicitly state the type for each of the rows. 
A["danceability"] = A["danceability"].astype(str)
A["duration"] = A["duration"].astype(str)
A["keysignature"] = A["keysignature"].astype(str)
A["tempo"] = A["tempo"].astype(str)
A["timesignature"] = A["timesignature"].astype(str)
A["title"] = A["title"].astype(str)
A["year"] = A["year"].astype(str)

feature_table = em.get_features_for_blocking(A, B)
#feature_table

########################################

# %%
######### TWO RULE BLOCKERS ################

rbt = em.RuleBasedBlocker()
rba = em.RuleBasedBlocker()

rule_title = rbt.add_rule(['title_title_jac_qgm_3_qgm_3(ltuple, rtuple) < 0.7'], feature_table)
#rule_artist = rba.add_rule(['artist_artist_jac_qgm_3_qgm_3(ltuple, rtuple) < 0.5'], feature_table)

candidates_t = rbt.block_tables(A, B, l_output_attrs=['title','artist','year'], r_output_attrs=['title','artist','year'])
#candidates_a = rba.block_tables(A, B, l_output_attrs=['title','artist','year'], r_output_attrs=['title','artist','year'])

candidates_t

#############################################
# Out:
# 0%                          100%
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:03:55
# 0%  100%
# []
# Finding pairs with missing value...
#            _id ltable_ID rtable_ID ltable_title  \
# 0            0    b12307        a5      Believe
# 1            1   b411738        a5      Believe
# 2            2   b561251        a5      Believe
# 3            3   b523378        a5      Believe
# 4            4   b488569        a5      Believe
# 5            5   b668803        a5      Believe
# 6            6   b207960        a5      Believe
# 7            7    b97375        a5      Believe
# 8            8   b332947        a5      Believe
# 9            9    b55400        a5      Believe
# 10          10   b632503        a5      Believe
# 11          11   b143482        a5      Believe
# 12          12   b385206        a5      Believe
# 13          13   b425144        a5      Believe
# 14          14   b465096        a5      Believe
# 15          15    b44230        a5      Believe
# 16          16   b254120        a5      Believe
# 17          17   b488674        a5      Believe
# 18          18   b639205        a5      Believe
# 19          19   b638186        a5      Believe
# 20          20    b17607        a5      Believe
# 21          21   b307454        a5      Believe
# 22          22   b810053        a5      Believe
# 23          23   b701758        a5      Believe
# 24          24   b652618        a5      Believe
# 25          25   b259363        a5      Believe
# 26          26   b240332        a5      Believe
# 27          27   b222510        a5      Believe
# 28          28    b78218        a5      Believe
# 29          29   b714090        a5      Believe
# ...        ...       ...       ...          ...
# 126453  126453   b753123    a33144         Home
# 126454  126454   b599524    a33144         Home
# 126455  126455   b385509    a33144         Home
# 126456  126456    b92087    a33144         Home
# 126457  126457   b594901    a33144         Home
# 126458  126458   b476661    a33144         Home
# 126459  126459    b15814    a33144         Home
# 126460  126460   b550393    a33144         Home
# 126461  126461   b255434    a33144         Home
# 126462  126462   b209358    a33144         Home
# 126463  126463   b709121    a33144         Home
# 126464  126464    b82681    a33144         Home
# 126465  126465   b401925    a33144         Home
# 126466  126466   b100311    a33144         Home
# 126467  126467   b466955    a33144         Home
# 126468  126468   b356993    a33144         Home
# 126469  126469   b740366    a33144         Home
# 126470  126470   b398863    a33144         Home
# 126471  126471   b352277    a33144         Home
# 126472  126472    b85989    a33144         Home
# 126473  126473    b40934    a33144         Home
# 126474  126474    b77295    a33144         Home
# 126475  126475   b116222    a33144         Home
# 126476  126476   b173041    a33144         Home
# 126477  126477   b412195    a33144         Home
# 126478  126478   b444294    a33144         Home
# 126479  126479   b604204    a33144         Home
# 126480  126480   b222204    a33144         Home
# 126481  126481   b475183    a33144         Home
# 126482  126482   b113152    a33144         Home
#
#                                 ltable_artist ltable_year rtable_title  \
# 0                                       Lasgo        2009      Believe
# 1                                         JVC           0      Believe
# 2                              Inland Knights           0      Believe
# 3                                Danny Wright           0      Believe
# 4                                    Ytheband           0      Believe
# 5                               Brooks & Dunn        2005      Believe
# 6                                        Stan           0      Believe
# 7                            Stephen Simmonds           0      Believe
# 8                                     Sebadoh        2007      Believe
# 9                                 Fanny Grace           0      Believe
# 10                                 Jon Secada        1999      Believe
# 11                                        JVC           0      Believe
# 12                                        Lox           0      Believe
# 13                           Q-Tip / D'Angelo        2008      Believe
# 14                              Flowing Tears        2004      Believe
# 15                               Soul II Soul           0      Believe
# 16                                      W & D           0      Believe
# 17                                   On Trial        2006      Believe
# 18                              Harry Toddler           0      Believe
# 19                                        JVC           0      Believe
# 20                                    Juniper           0      Believe
# 21                                      Savon        2004      Believe
# 22                         Backyard Tire Fire        2005      Believe
# 23                                    NOSTRUM           0      Believe
# 24      Helena Noguerra / Federico Pellegrini           0      Believe
# 25                         Echoing Green_ The        1998      Believe
# 26                              RIDDLIN' KIDS        2002      Believe
# 27                               Britt Nicole        2007      Believe
# 28                                   Mainstay        2007      Believe
# 29                             The Muckrakers           0      Believe
# ...                                       ...         ...          ...
# 126453                          Donna Gardier        2006         Home
# 126454                            Dave Barnes           0         Home
# 126455             Peter Green Splinter Group        2001         Home
# 126456                      Mr. Irish Bastard        2006         Home
# 126457                        LCD Soundsystem        2010         Home
# 126458                            Gemma Hayes        2008         Home
# 126459     Edward Sharpe & The Magnetic Zeros        2009         Home
# 126460                             Will Young        2005         Home
# 126461                            Panu Larnos        2007         Home
# 126462                           Scott McKeon           0         Home
# 126463                       Basil Poledouris        1987         Home
# 126464                              Joey Cape        2008         Home
# 126465                        Chris Christian           0         Home
# 126466                          Minnie Driver        2004         Home
# 126467                               Bonepony           0         Home
# 126468                           Rich Mullins        1999         Home
# 126469                         Gabriel Gordon        2003         Home
# 126470                             Jami Smith        1999         Home
# 126471                   Chick Corea / Origin           0         Home
# 126472                           Rose Cousins        2006         Home
# 126473                          Monster Movie        2002         Home
# 126474                           Ryan Malcolm           0         Home
# 126475                         Icecream Hands        1993         Home
# 126476                                   Wah!           0         Home
# 126477                                   Kyte        2007         Home
# 126478                              She & Him        2010         Home
# 126479                            Greg Keelor        1997         Home
# 126480                         Ron Clearfield           0         Home
# 126481        Working For A Nuclear Free City        2006         Home
# 126482                          Outputmessage        2004         Home
#
#        rtable_artist rtable_year
# 0       Blue October           —
# 1       Blue October           —
# 2       Blue October           —
# 3       Blue October           —
# 4       Blue October           —
# 5       Blue October           —
# 6       Blue October           —
# 7       Blue October           —
# 8       Blue October           —
# 9       Blue October           —
# 10      Blue October           —
# 11      Blue October           —
# 12      Blue October           —
# 13      Blue October           —
# 14      Blue October           —
# 15      Blue October           —
# 16      Blue October           —
# 17      Blue October           —
# 18      Blue October           —
# 19      Blue October           —
# 20      Blue October           —
# 21      Blue October           —
# 22      Blue October           —
# 23      Blue October           —
# 24      Blue October           —
# 25      Blue October           —
# 26      Blue October           —
# 27      Blue October           —
# 28      Blue October           —
# 29      Blue October           —
# ...              ...         ...
# 126453   Sheryl Crow           —
# 126454   Sheryl Crow           —
# 126455   Sheryl Crow           —
# 126456   Sheryl Crow           —
# 126457   Sheryl Crow           —
# 126458   Sheryl Crow           —
# 126459   Sheryl Crow           —
# 126460   Sheryl Crow           —
# 126461   Sheryl Crow           —
# 126462   Sheryl Crow           —
# 126463   Sheryl Crow           —
# 126464   Sheryl Crow           —
# 126465   Sheryl Crow           —
# 126466   Sheryl Crow           —
# 126467   Sheryl Crow           —
# 126468   Sheryl Crow           —
# 126469   Sheryl Crow           —
# 126470   Sheryl Crow           —
# 126471   Sheryl Crow           —
# 126472   Sheryl Crow           —
# 126473   Sheryl Crow           —
# 126474   Sheryl Crow           —
# 126475   Sheryl Crow           —
# 126476   Sheryl Crow           —
# 126477   Sheryl Crow           —
# 126478   Sheryl Crow           —
# 126479   Sheryl Crow           —
# 126480   Sheryl Crow           —
# 126481   Sheryl Crow           —
# 126482   Sheryl Crow           —
#
# [126483 rows x 9 columns]

# %%
######### BLACK BOX BLOCKER (Currently too slow) ################

#bb = em.BlackBoxBlocker()
#def my_function(x, y):
    # x, y will be of type pandas series
    
    # get artist attribute's first letter
    #x_artist = x['artist'][0]
    #y_artist = y['artist'][0]
    #if x_artist != y_artist:
    #    return True
    #else:
    #    return False

#bb.set_black_box_function(my_function)

#relaxed_artist = bb.block_tables(A, B, l_output_attrs=['artist', 'title', 'year'], r_output_attrs=['artist', 'title', 'year'])
#relaxed_artist

#############################################

# %%
### reduce candidate set size to candidates_final ###
cf = open('../../csv/candidates_final.csv', 'w')
cf.write("id,ltable_ID,rtable_ID,ltable_title,ltable_artist,ltable_year,rtable_title,rtable_artist,rtable_year\n")
ID = 0
for i, row in candidates_t.iterrows():
    lt_a = row['ltable_artist']
    rt_a = row['rtable_artist']
    
    if lt_a[0] == rt_a[0]:
        cf.write(str(ID)+","+row['ltable_ID']+","+row['rtable_ID']+","+row['ltable_title']+","+row['ltable_artist']+","+row['ltable_year']+","+row['rtable_title']+","+row['rtable_artist']+","+row['rtable_year']+"\n")
        ID+=1
        
cf
# Out:
# <_io.TextIOWrapper name='../../csv/candidates_final.csv' mode='w' encoding='UTF-8'>

# %%
#### INTERSECTION BY SIMILAR TUPLE PAIRS ####
#union = pd.merge(candidates_t, relaxed_artist, on=['ltable_ID','rtable_ID'])
#union

# %%
#em.to_csv_metadata(candidates_t, '../../csv/candidate_set.csv')
