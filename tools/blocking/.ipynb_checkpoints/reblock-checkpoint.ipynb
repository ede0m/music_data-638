# %%
import py_entitymatching as em
import pandas as pd
import os

# %%
######### READING IN TABLES ############

path_a = os.path.join(os.getcwd(), "../../csv/msd_final.csv" )
path_b = os.path.join(os.getcwd(), "../../csv/musicbrainz_final.csv")

A = em.read_csv_metadata(path_a, key='ID')
B = em.read_csv_metadata(path_b, key='ID')

#########################################
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.
# /home/garritt/.local/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2821: DtypeWarning: Columns (3,4,5,6,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# Metadata file is not present in the given path; proceeding to read the csv file.

# %%
########### FEATURE RULES ##############

## Explicitly state the type for each of the rows. 
A["danceability"] = A["danceability"].astype(str)
A["duration"] = A["duration"].astype(str)
A["keysignature"] = A["keysignature"].astype(str)
A["tempo"] = A["tempo"].astype(str)
A["timesignature"] = A["timesignature"].astype(str)
A["title"] = A["title"].astype(str)
A["year"] = A["year"].astype(str)

feature_table = em.get_features_for_blocking(A, B)
feature_table

########################################
# Out:
#                          feature_name left_attribute right_attribute  \
# 0                      ID_ID_lev_dist             ID              ID
# 1                       ID_ID_lev_sim             ID              ID
# 2                           ID_ID_jar             ID              ID
# 3                           ID_ID_jwn             ID              ID
# 4                           ID_ID_exm             ID              ID
# 5               ID_ID_jac_qgm_3_qgm_3             ID              ID
# 6       artist_artist_jac_qgm_3_qgm_3         artist          artist
# 7   artist_artist_cos_dlm_dc0_dlm_dc0         artist          artist
# 8   artist_artist_jac_dlm_dc0_dlm_dc0         artist          artist
# 9                   artist_artist_mel         artist          artist
# 10             artist_artist_lev_dist         artist          artist
# 11              artist_artist_lev_sim         artist          artist
# 12                  artist_artist_nmw         artist          artist
# 13                   artist_artist_sw         artist          artist
# 14        title_title_jac_qgm_3_qgm_3          title           title
# 15    title_title_cos_dlm_dc0_dlm_dc0          title           title
# 16    title_title_jac_dlm_dc0_dlm_dc0          title           title
# 17                    title_title_mel          title           title
# 18               title_title_lev_dist          title           title
# 19                title_title_lev_sim          title           title
# 20                    title_title_nmw          title           title
# 21                     title_title_sw          title           title
# 22                 year_year_lev_dist           year            year
# 23                  year_year_lev_sim           year            year
# 24                      year_year_jar           year            year
# 25                      year_year_jwn           year            year
# 26                      year_year_exm           year            year
# 27          year_year_jac_qgm_3_qgm_3           year            year
#
#    left_attr_tokenizer right_attr_tokenizer       simfunction  \
# 0                 None                 None          lev_dist
# 1                 None                 None           lev_sim
# 2                 None                 None              jaro
# 3                 None                 None      jaro_winkler
# 4                 None                 None       exact_match
# 5                qgm_3                qgm_3           jaccard
# 6                qgm_3                qgm_3           jaccard
# 7              dlm_dc0              dlm_dc0            cosine
# 8              dlm_dc0              dlm_dc0           jaccard
# 9                 None                 None       monge_elkan
# 10                None                 None          lev_dist
# 11                None                 None           lev_sim
# 12                None                 None  needleman_wunsch
# 13                None                 None    smith_waterman
# 14               qgm_3                qgm_3           jaccard
# 15             dlm_dc0              dlm_dc0            cosine
# 16             dlm_dc0              dlm_dc0           jaccard
# 17                None                 None       monge_elkan
# 18                None                 None          lev_dist
# 19                None                 None           lev_sim
# 20                None                 None  needleman_wunsch
# 21                None                 None    smith_waterman
# 22                None                 None          lev_dist
# 23                None                 None           lev_sim
# 24                None                 None              jaro
# 25                None                 None      jaro_winkler
# 26                None                 None       exact_match
# 27               qgm_3                qgm_3           jaccard
#
#                                                           function  \
# 0                      <function ID_ID_lev_dist at 0x7f6e2c5fcf28>
# 1                       <function ID_ID_lev_sim at 0x7f6e47668bf8>
# 2                           <function ID_ID_jar at 0x7f6e476689d8>
# 3                           <function ID_ID_jwn at 0x7f6e4766dd08>
# 4                           <function ID_ID_exm at 0x7f6e4766dc80>
# 5               <function ID_ID_jac_qgm_3_qgm_3 at 0x7f6e4766d268>
# 6       <function artist_artist_jac_qgm_3_qgm_3 at 0x7f6e4766d378>
# 7   <function artist_artist_cos_dlm_dc0_dlm_dc0 at 0x7f6e3d5daea0>
# 8   <function artist_artist_jac_dlm_dc0_dlm_dc0 at 0x7f6e3d5dae18>
# 9                   <function artist_artist_mel at 0x7f6e3d5dad90>
# 10             <function artist_artist_lev_dist at 0x7f6e3d5daf28>
# 11              <function artist_artist_lev_sim at 0x7f6e3a27d048>
# 12                  <function artist_artist_nmw at 0x7f6e3a27d0d0>
# 13                   <function artist_artist_sw at 0x7f6e3a27d158>
# 14        <function title_title_jac_qgm_3_qgm_3 at 0x7f6e3a27d1e0>
# 15    <function title_title_cos_dlm_dc0_dlm_dc0 at 0x7f6e3a27d268>
# 16    <function title_title_jac_dlm_dc0_dlm_dc0 at 0x7f6e3a27d2f0>
# 17                    <function title_title_mel at 0x7f6e3a27d378>
# 18               <function title_title_lev_dist at 0x7f6e3a27d400>
# 19                <function title_title_lev_sim at 0x7f6e3a27d488>
# 20                    <function title_title_nmw at 0x7f6e3a27d510>
# 21                     <function title_title_sw at 0x7f6e3a27d598>
# 22                 <function year_year_lev_dist at 0x7f6e3a27d620>
# 23                  <function year_year_lev_sim at 0x7f6e3a27d6a8>
# 24                      <function year_year_jar at 0x7f6e3a27d730>
# 25                      <function year_year_jwn at 0x7f6e3a27d7b8>
# 26                      <function year_year_exm at 0x7f6e3a27d840>
# 27          <function year_year_jac_qgm_3_qgm_3 at 0x7f6e3a27d8c8>
#
#                                                                                         function_source  \
# 0   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 1   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 2   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 3   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 4   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 5   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 6   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 7   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 8   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 9   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 10  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 11  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 12  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 13  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 14  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 15  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 16  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 17  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 18  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 19  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 20  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 21  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 22  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 23  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 24  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 25  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 26  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 27  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
#
#    is_auto_generated
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10              True
# 11              True
# 12              True
# 13              True
# 14              True
# 15              True
# 16              True
# 17              True
# 18              True
# 19              True
# 20              True
# 21              True
# 22              True
# 23              True
# 24              True
# 25              True
# 26              True
# 27              True

# %%
######### TWO RULE BLOCKERS ################

rbt = em.RuleBasedBlocker()
rba = em.RuleBasedBlocker()

#rule_title = rbt.add_rule(['title_title_jac_qgm_3_qgm_3(ltuple, rtuple) < 0.5'], feature_table)
rule_title = rbt.add_rule(['title_title_jac_qgm_3_qgm_3(ltuple, rtuple) < 0.7'], feature_table)

#rule_artist = rba.add_rule(['artist_artist_jac_qgm_3_qgm_3(ltuple, rtuple) < 0.5'], feature_table)

candidates_t = rbt.block_tables(A, B, l_output_attrs=['title','artist','year'], r_output_attrs=['title','artist','year'])
#candidates_a = rba.block_tables(A, B, l_output_attrs=['title','artist','year'], r_output_attrs=['title','artist','year'])

candidates_t

#############################################
# Out:
# 0%                          100%
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:08:24
# 0%  100%
# []
# Finding pairs with missing value...
#            _id ltable_ID rtable_ID   ltable_title  \
# 0            0   b802976        a5      I Believe
# 1            1   b194772        a5      I Believe
# 2            2   b639205        a5        Believe
# 3            3   b327911        a5      I Believe
# 4            4   b721246        a5      I Believe
# 5            5   b737698        a5      I Believe
# 6            6   b410116        a5  Believe In Me
# 7            7   b688705        a5      I Believe
# 8            8   b311928        a5     We Believe
# 9            9   b262732        a5      I Believe
# 10          10   b410277        a5        Believe
# 11          11   b295612        a5      I Believe
# 12          12   b390665        a5       Believer
# 13          13   b820183        a5        Believe
# 14          14   b508935        a5        Believe
# 15          15   b328753        a5     Believe Me
# 16          16   b328756        a5      I Believe
# 17          17   b115723        a5      I Believe
# 18          18    b99352        a5      I Believe
# 19          19   b378118        a5      I Believe
# 20          20   b656650        a5      I Believe
# 21          21    b50429        a5        Believe
# 22          22    b66834        a5      Believers
# 23          23   b558405        a5      I Believe
# 24          24   b165157        a5      I Believe
# 25          25   b378215        a5      I Believe
# 26          26   b673175        a5      I Believe
# 27          27   b198206        a5      I Believe
# 28          28   b378501        a5      I Believe
# 29          29   b567445        a5      I Believe
# ...        ...       ...       ...            ...
# 308580  308580   b678639    a33144           Home
# 308581  308581   b359257    a33144           Home
# 308582  308582   b629641    a33144           Home
# 308583  308583   b744493    a33144           Home
# 308584  308584   b425024    a33144           Home
# 308585  308585   b269348    a33144           Home
# 308586  308586   b113711    a33144           Home
# 308587  308587   b408693    a33144           Home
# 308588  308588   b187482    a33144           Home
# 308589  308589   b113864    a33144           Home
# 308590  308590    b72920    a33144           Home
# 308591  308591    b89451    a33144           Home
# 308592  308592   b753123    a33144           Home
# 308593  308593    b96841    a33144           Home
# 308594  308594    b15814    a33144           Home
# 308595  308595   b214273    a33144           Home
# 308596  308596   b786194    a33144           Home
# 308597  308597     b7751    a33144           Home
# 308598  308598    b40551    a33144           Home
# 308599  308599   b360100    a33144           Home
# 308600  308600   b466606    a33144           Home
# 308601  308601   b466683    a33144           Home
# 308602  308602   b786232    a33144           Home
# 308603  308603    b98147    a33144   Home vs Home
# 308604  308604   b253872    a33144           Home
# 308605  308605   b133791    a33144           Home
# 308606  308606   b466955    a33144           Home
# 308607  308607   b352277    a33144           Home
# 308608  308608    b40934    a33144           Home
# 308609  308609   b475183    a33144           Home
#
#                                ltable_artist ltable_year rtable_title  \
# 0                             Happy Clappers        1995      Believe
# 1                          Celebrate The Nun        1991      Believe
# 2                              Harry Toddler           0      Believe
# 3       Jonny Lang with Fisk Jubilee Singers           0      Believe
# 4                      Heidi Marie Vestrheim        2004      Believe
# 5                                  Melanie B        2000      Believe
# 6                                       Endo           0      Believe
# 7                        Seventh Day Slumber        1999      Believe
# 8                                   Nouveaux           0      Believe
# 9                        Simian Mobile Disco        2006      Believe
# 10                                K's Choice        1998      Believe
# 11                          The Prayer Chain        1991      Believe
# 12                                 Goldfrapp        2010      Believe
# 13                          Q-Tip / D'Angelo        2008      Believe
# 14                                    Celtus        1999      Believe
# 15                                     Tonic           0      Believe
# 16                             Laurel Aitken        1999      Believe
# 17                            The Grip Weeds           0      Believe
# 18                            Happy Clappers        1995      Believe
# 19                                  H-Blockx        2004      Believe
# 20                                Tigertailz        1995      Believe
# 21                                       Lox           0      Believe
# 22                                Jan Leyers           0      Believe
# 23                              Dolly Parton        2004      Believe
# 24                                        Ra           0      Believe
# 25                             Tammy Wynette           0      Believe
# 26                          Hothouse Flowers           0      Believe
# 27                                Dee Robert        2004      Believe
# 28                   Christer Sj\xc3\xb6gren           0      Believe
# 29                             Andy Williams           0      Believe
# ...                                      ...         ...          ...
# 308580                  The Dangerous Summer        2007         Home
# 308581                          Roger Waters        1987         Home
# 308582                          Naked Raygun           0         Home
# 308583                          Heideroosjes        2001         Home
# 308584                               Aerovox           0         Home
# 308585                              Daughtry        2006         Home
# 308586                             Engineers        2004         Home
# 308587                         Moses Wiggins           0         Home
# 308588                       Vanessa Carlton        2007         Home
# 308589                            E.G. Daily        1999         Home
# 308590                               Kenny G        1988         Home
# 308591                           Sean Lennon        1998         Home
# 308592                         Donna Gardier        2006         Home
# 308593      Paul van Dyk Feat. Johnny McDaid        1996         Home
# 308594    Edward Sharpe & The Magnetic Zeros        2009         Home
# 308595                      Brian Lane Green           0         Home
# 308596               David Byrne & Brian Eno        2008         Home
# 308597                          David Hudson           0         Home
# 308598                           Jane Birkin        2006         Home
# 308599                               O'Death        2008         Home
# 308600                       Triinu Kivilaan        2008         Home
# 308601                          Karla Bonoff        1977         Home
# 308602                          Joe Satriani        1995         Home
# 308603              The Xcerts/The Blueskies           0         Home
# 308604                           Cat Stevens        1975         Home
# 308605                     Beatnik Filmstars           0         Home
# 308606                              Bonepony           0         Home
# 308607                  Chick Corea / Origin           0         Home
# 308608                         Monster Movie        2002         Home
# 308609       Working For A Nuclear Free City        2006         Home
#
#        rtable_artist rtable_year
# 0       Blue October           —
# 1       Blue October           —
# 2       Blue October           —
# 3       Blue October           —
# 4       Blue October           —
# 5       Blue October           —
# 6       Blue October           —
# 7       Blue October           —
# 8       Blue October           —
# 9       Blue October           —
# 10      Blue October           —
# 11      Blue October           —
# 12      Blue October           —
# 13      Blue October           —
# 14      Blue October           —
# 15      Blue October           —
# 16      Blue October           —
# 17      Blue October           —
# 18      Blue October           —
# 19      Blue October           —
# 20      Blue October           —
# 21      Blue October           —
# 22      Blue October           —
# 23      Blue October           —
# 24      Blue October           —
# 25      Blue October           —
# 26      Blue October           —
# 27      Blue October           —
# 28      Blue October           —
# 29      Blue October           —
# ...              ...         ...
# 308580   Sheryl Crow           —
# 308581   Sheryl Crow           —
# 308582   Sheryl Crow           —
# 308583   Sheryl Crow           —
# 308584   Sheryl Crow           —
# 308585   Sheryl Crow           —
# 308586   Sheryl Crow           —
# 308587   Sheryl Crow           —
# 308588   Sheryl Crow           —
# 308589   Sheryl Crow           —
# 308590   Sheryl Crow           —
# 308591   Sheryl Crow           —
# 308592   Sheryl Crow           —
# 308593   Sheryl Crow           —
# 308594   Sheryl Crow           —
# 308595   Sheryl Crow           —
# 308596   Sheryl Crow           —
# 308597   Sheryl Crow           —
# 308598   Sheryl Crow           —
# 308599   Sheryl Crow           —
# 308600   Sheryl Crow           —
# 308601   Sheryl Crow           —
# 308602   Sheryl Crow           —
# 308603   Sheryl Crow           —
# 308604   Sheryl Crow           —
# 308605   Sheryl Crow           —
# 308606   Sheryl Crow           —
# 308607   Sheryl Crow           —
# 308608   Sheryl Crow           —
# 308609   Sheryl Crow           —
#
# [308610 rows x 9 columns]

# %%
######### BLACK BOX BLOCKER (Currently too slow) ################

#bb = em.BlackBoxBlocker()
#def my_function(x, y):
    # x, y will be of type pandas series
    
    # get artist attribute's first letter
    #x_artist = x['artist'][0]
    #y_artist = y['artist'][0]
    #if x_artist != y_artist:
    #    return True
    #else:
    #    return False

#bb.set_black_box_function(my_function)

#relaxed_artist = bb.block_tables(A, B, l_output_attrs=['artist', 'title', 'year'], r_output_attrs=['artist', 'title', 'year'])
#relaxed_artist

#############################################

# %%
### reduce candidate set size to candidates_final ###
cf = open('../../csv/candidates_final.csv', 'w')
cf.write("id,ltable_ID,rtable_ID,ltable_title,ltable_artist,ltable_year,rtable_title,rtable_artist,rtable_year\n")
ID = 0
for i, row in candidates_t.iterrows():
    lt_a = row['ltable_artist']
    rt_a = row['rtable_artist']
    
    if lt_a[0] == rt_a[0]:
        cf.write(str(ID)+","+row['ltable_ID']+","+row['rtable_ID']+","+row['ltable_title']+","+row['ltable_artist']+","+row['ltable_year']+","+row['rtable_title']+","+row['rtable_artist']+","+row['rtable_year']+"\n")
        ID+=1
        
cf
# Out:
# <_io.TextIOWrapper name='../../csv/candidates_final_2.csv' mode='w' encoding='UTF-8'>

# %%
#### INTERSECTION BY SIMILAR TUPLE PAIRS ####
#union = pd.merge(candidates_t, relaxed_artist, on=['ltable_ID','rtable_ID'])
#union

# %%
#em.to_csv_metadata(candidates_t, '../../csv/candidate_set.csv')
