# %%
## Import the necessary packages that will be used for blocking 
import py_stringsimjoin as ssj
import py_stringmatching as sm
import py_entitymatching as em
import pandas as pd
import os, sys

# %%
print('python version: ' + sys.version)
print('py_stringsimjoin version: ' + ssj.__version__)
print('py_stringmatching version: ' + sm.__version__)
print('py_entitymatching version: ' + em.__version__)
print('pandas version: ' + pd.__version__)
# Out:
# python version: 3.5.2 (v3.5.2:4def2a2901a5, Jun 26 2016, 10:47:25)
# [GCC 4.2.1 (Apple Inc. build 5666) (dot 3)]
# py_stringsimjoin version: 0.1.0
# py_stringmatching version: 0.2.1
# py_entitymatching version: 0.1.0
# pandas version: 0.19.1

# %%
## ^ represents the current python environment that we will be
## performing our blocking in

# %%
## Pathway to the msd csv file that was acquired from parsing
## the data dump
msd_table_path = os.path.join(os.getcwd(),"../../", "csv", "msd_final.csv")

# %%
print(msd_table_path)
# Out:
# /Users/garritt/CODEDOG/scrapy/638/music_data-638/tools/blocking/../../csv/msd_final.csv

# %%
## Using pandas, we read in the CSV file and convert it into a data
## frame that we will be able to utilize for entity matching
MSD_TABLE = pd.read_csv(msd_table_path)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (3,4,5,6,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
## Display table
MSD_TABLE
# Out:
#              ID  \
# 0            b1
# 1            b2
# 2            b3
# 3            b4
# 4            b5
# 5            b6
# 6            b7
# 7            b8
# 8            b9
# 9           b10
# 10          b11
# 11          b12
# 12          b13
# 13          b14
# 14          b15
# 15          b16
# 16          b17
# 17          b18
# 18          b19
# 19          b20
# 20          b21
# 21          b22
# 22          b23
# 23          b24
# 24          b25
# 25          b26
# 26          b27
# 27          b28
# 28          b29
# 29          b30
# ...         ...
# 347228  b347229
# 347229  b347230
# 347230  b347231
# 347231  b347232
# 347232  b347233
# 347233  b347234
# 347234  b347235
# 347235  b347236
# 347236  b347237
# 347237  b347238
# 347238  b347239
# 347239  b347240
# 347240  b347241
# 347241  b347242
# 347242  b347243
# 347243  b347244
# 347244  b347245
# 347245  b347246
# 347246  b347247
# 347247  b347248
# 347248  b347249
# 347249  b347250
# 347250  b347251
# 347251  b347252
# 347252  b347253
# 347253  b347254
# 347254  b347255
# 347255  b347256
# 347256  b347257
# 347257  b347258
#
#                                                                              album  \
# 0                                                               Saturday Nite Live
# 1                                                                     Adelitas Way
# 2                                                                        Cognicide
# 3                                                                      Fear Itself
# 4                                                                          Forever
# 5                                                                       Dimensions
# 6                                                            A Bad Azz Mix Tape IV
# 7                                                                       Surrender!
# 8                                                                     Be a Brother
# 9                                                                      In Memoriam
# 10                                             Las Numero 1 De La Sonora Santanera
# 11                                                        Vile Pervert - The Music
# 12                                                                 Twentysomething
# 13                                                                   Friend Or Foe
# 14                                                                         Colours
# 15                                                                  Inside / Asent
# 16                                                                   Muertos Vivos
# 17                                                                       Die Stadt
# 18                                                                         Jamoree
# 19                                                      \xc3\x96rd\xc3\x6gi Angyal
# 20                                                              F\xc3\x8rr Ei Dame
# 21                                                           Bring Ya To The Brink
# 26                                              Conquest of Paradise     rock
# 27                                                      What Is Life      pop
# 28                                                       Bangla Desh      pop
# 29                             Give Me Love (Give Me Peace on Earth)      pop
# ...                                                              ...      ...
# 19123                                                         Gloria  country
# 19124                        Have I Told You Lately That I Love You?  country
# 19125                                                 Days Like This  country
# 19126                                                   Sign of Love  country
# 19127                                                    Angry World  country
# 19128                                                     Hitchhiker  country
# 19129                                                   Love and War  country
# 19130                                      Peaceful Valley Boulevard  country
# 19131                                            My Favorite Mistake  country
# 19132                                              Anything but Down  country
# 19133                                              Anything But Down  country
# 19134                                                Soak Up the Sun  country
# 19135                                                  Steve McQueen  country
# 19136                                                    No Religion  country
# 19137                                                    Perfect Fit  country
# 19138                                          Rough God Goes Riding  country
# 19139                                               The Healing Game  country
# 19140                                                       Rumblin'  country
# 19141                                     Someone's Gonna Rescue You  country
# 19142                                                   Walk With Me  country
# 19143                                                       Dead Man  country
# 19144                                     Someone's Gonna Rescue You  country
# 19145                                                   It's So Easy  country
# 19146                                   The First Cut Is the Deepest  country
# 19147                                                   Good Is Good  country
# 19148                                                  Not Fade Away  country
# 19149                                                  Precious Time  country
# 19150                                       Woman in the White House  country
# 19151                                                           Easy  country
# 19152                                                           Home  country
#
#        year
# 0         —
# 1         —
# 2      2014
# 3      2014
# 4      2014
# 5      1970
# 6      2004
# 7      2004
# 8      1977
# 9      2007
# 10     2009
# 11     2010
# 12     1995
# 13     1996
# 14     2013
# 15     2013
# 16     2003
# 17     2013
# 18     2010
# 19     2010
# 20     2011
# 21     2012
# 22     2015
# 23        —
# 24        —
# 25        —
# 26     1994
# 27     1970
# 28     1971
# 29     1973
# ...     ...
# 19123  1993
# 19124  1995
# 19125  1995
# 19126  2011
# 19127  2012
# 19128  2012
# 19129  2012
# 19130  2012
# 19131  1998
# 19132  1999
# 19133  1999
# 19134  2002
# 19135  2002
# 19136  1995
# 19137  1995
# 19138  1997
# 19139  1997
# 19140  2012
# 19141  2012
# 19142  2012
# 19143     —
# 19144     —
# 19145  2003
# 19146  2003
# 19147  2005
# 19148  2007
# 19149  1999
# 19150  2012
# 19151  2013
# 19152     —
#
# [19153 rows x 5 columns]

# %%
## Make a profile table for MSD_TABLE to give us a better idea
## on what our key attribute will be as well as which attributes
## will be most benificial in blocking

# %%
ssj.profile_table_for_join(MSD_TABLE)
# Out:
#                  Unique values Missing values  \
# Attribute
# ID             347258 (100.0%)       0 (0.0%)
# album          113785 (32.77%)       0 (0.0%)
# artist          50936 (14.67%)       0 (0.0%)
# danceability          3 (0.0%)       0 (0.0%)
# duration        35455 (10.21%)       0 (0.0%)
# keySignature        25 (0.01%)       0 (0.0%)
# tempo          135116 (38.91%)       0 (0.0%)
# timeSignature        13 (0.0%)       0 (0.0%)
# title          275277 (79.27%)       5 (0.0%)
# year               164 (0.05%)       0 (0.0%)
#
#                                                      Comments
# Attribute
# ID             This attribute can be used as a key attribute.
# album
# artist
# danceability
# duration
# keySignature
# tempo
# timeSignature
# title
# year

# %%
## Make a profile table for MBRAINZ_TABLE to give us a better idea
## on what our key attribute will be as well as which attributes
## will be most benificial in blocking
ssj.profile_table_for_join(MBRAINZ_TABLE)
# Out:
#             Unique values Missing values  \
# Attribute
# ID         19153 (100.0%)       0 (0.0%)
# artist      3857 (20.14%)       0 (0.0%)
# title      13096 (68.38%)       0 (0.0%)
# Genre          11 (0.06%)       0 (0.0%)
# year           94 (0.49%)       0 (0.0%)
#
#                                                  Comments
# Attribute
# ID         This attribute can be used as a key attribute.
# artist
# title
# Genre
# year

# %%
## Explicitly state the type for each of the rows. 
MSD_TABLE["danceability"] = MSD_TABLE["danceability"].astype(str)
MSD_TABLE["duration"] = MSD_TABLE["duration"].astype(str)
MSD_TABLE["keySignature"] = MSD_TABLE["keySignature"].astype(str)
MSD_TABLE["tempo"] = MSD_TABLE["tempo"].astype(str)
MSD_TABLE["timeSignature"] = MSD_TABLE["timeSignature"].astype(str)
MSD_TABLE["title"] = MSD_TABLE["title"].astype(str)
MSD_TABLE["year"] = MSD_TABLE["year"].astype(str)

# %%
# Rule-based blocking over input tables
# first get features that can be used
feature_table = em.get_features_for_blocking(MSD_TABLE, MBRAINZ_TABLE)
feature_table
# Out:
#                          feature_name left_attribute right_attribute  \
# 0                      ID_ID_lev_dist             ID              ID
# 1                       ID_ID_lev_sim             ID              ID
# 2                           ID_ID_jar             ID              ID
# 3                           ID_ID_jwn             ID              ID
# 4                           ID_ID_exm             ID              ID
# 5               ID_ID_jac_qgm_3_qgm_3             ID              ID
# 6       artist_artist_jac_qgm_3_qgm_3         artist          artist
# 7   artist_artist_cos_dlm_dc0_dlm_dc0         artist          artist
# 8   artist_artist_jac_dlm_dc0_dlm_dc0         artist          artist
# 9                   artist_artist_mel         artist          artist
# 10             artist_artist_lev_dist         artist          artist
# 11              artist_artist_lev_sim         artist          artist
# 12                  artist_artist_nmw         artist          artist
# 13                   artist_artist_sw         artist          artist
# 14        title_title_jac_qgm_3_qgm_3          title           title
# 15    title_title_cos_dlm_dc0_dlm_dc0          title           title
# 16    title_title_jac_dlm_dc0_dlm_dc0          title           title
# 17                    title_title_mel          title           title
# 18               title_title_lev_dist          title           title
# 19                title_title_lev_sim          title           title
# 20                    title_title_nmw          title           title
# 21                     title_title_sw          title           title
# 22                 year_year_lev_dist           year            year
# 23                  year_year_lev_sim           year            year
# 24                      year_year_jar           year            year
# 25                      year_year_jwn           year            year
# 26                      year_year_exm           year            year
# 27          year_year_jac_qgm_3_qgm_3           year            year
#
#    left_attr_tokenizer right_attr_tokenizer       simfunction  \
# 0                 None                 None          lev_dist
# 1                 None                 None           lev_sim
# 2                 None                 None              jaro
# 3                 None                 None      jaro_winkler
# 4                 None                 None       exact_match
# 5                qgm_3                qgm_3           jaccard
# 6                qgm_3                qgm_3           jaccard
# 7              dlm_dc0              dlm_dc0            cosine
# 8              dlm_dc0              dlm_dc0           jaccard
# 9                 None                 None       monge_elkan
# 10                None                 None          lev_dist
# 11                None                 None           lev_sim
# 12                None                 None  needleman_wunsch
# 13                None                 None    smith_waterman
# 14               qgm_3                qgm_3           jaccard
# 15             dlm_dc0              dlm_dc0            cosine
# 16             dlm_dc0              dlm_dc0           jaccard
# 17                None                 None       monge_elkan
# 18                None                 None          lev_dist
# 19                None                 None           lev_sim
# 20                None                 None  needleman_wunsch
# 21                None                 None    smith_waterman
# 22                None                 None          lev_dist
# 23                None                 None           lev_sim
# 24                None                 None              jaro
# 25                None                 None      jaro_winkler
# 26                None                 None       exact_match
# 27               qgm_3                qgm_3           jaccard
#
#                                                        function  \
# 0                      <function ID_ID_lev_dist at 0x10661c6a8>
# 1                       <function ID_ID_lev_sim at 0x109bd2d90>
# 2                           <function ID_ID_jar at 0x1048ded08>
# 3                           <function ID_ID_jwn at 0x109e51268>
# 4                           <function ID_ID_exm at 0x109e51048>
# 5               <function ID_ID_jac_qgm_3_qgm_3 at 0x109e51158>
# 6       <function artist_artist_jac_qgm_3_qgm_3 at 0x109e510d0>
# 7   <function artist_artist_cos_dlm_dc0_dlm_dc0 at 0x109e51488>
# 8   <function artist_artist_jac_dlm_dc0_dlm_dc0 at 0x109e51510>
# 9                   <function artist_artist_mel at 0x109e51598>
# 10             <function artist_artist_lev_dist at 0x109e51620>
# 11              <function artist_artist_lev_sim at 0x109e516a8>
# 12                  <function artist_artist_nmw at 0x109e51730>
# 13                   <function artist_artist_sw at 0x109e517b8>
# 14        <function title_title_jac_qgm_3_qgm_3 at 0x109e51840>
# 15    <function title_title_cos_dlm_dc0_dlm_dc0 at 0x109e518c8>
# 16    <function title_title_jac_dlm_dc0_dlm_dc0 at 0x109e51950>
# 17                    <function title_title_mel at 0x109e519d8>
# 18               <function title_title_lev_dist at 0x109e51a60>
# 19                <function title_title_lev_sim at 0x109e51ae8>
# 20                    <function title_title_nmw at 0x109e51b70>
# 21                     <function title_title_sw at 0x109e51bf8>
# 22                 <function year_year_lev_dist at 0x109e51c80>
# 23                  <function year_year_lev_sim at 0x109e51d08>
# 24                      <function year_year_jar at 0x109e51d90>
# 25                      <function year_year_jwn at 0x109e51e18>
# 26                      <function year_year_exm at 0x109e51ea0>
# 27          <function year_year_jac_qgm_3_qgm_3 at 0x109e51f28>
#
#                                                                                         function_source  \
# 0   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 1   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 2   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 3   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 4   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 5   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 6   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 7   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 8   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 9   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 10  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 11  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 12  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 13  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 14  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 15  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 16  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 17  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 18  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 19  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 20  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 21  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 22  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 23  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 24  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 25  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 26  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 27  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
#
#    is_auto_generated
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10              True
# 11              True
# 12              True
# 13              True
# 14              True
# 15              True
# 16              True
# 17              True
# 18              True
# 19              True
# 20              True
# 21              True
# 22              True
# 23              True
# 24              True
# 25              True
# 26              True
# 27              True

# %%
## Upon viewing the profiles for both tables above as well as the feature table, we will proceed
## with blocking on the "Title" attribute from MSD_TABLE and the 
## "Song" attribute from MBRAINZ_TABLE. Both of these attributes have
## a high uniqueness which will provide useful when blocking

# %%
## We will have two different tokenizers to compare blocking results.
## The first is a tokenization by whitespace while the second is a 
## 3-gram tokenization. Both will be used with the Jacaard score to
## determine how similar the tuples are.
ws = sm.WhitespaceTokenizer(return_set=True)
gram3 = sm.QgramTokenizer(qval=3)

# %%
## Using the whitespace tokenization, we will set our similarity 
## score threshold to be 0.5. This means that the tokens will have to

# %%
## share at least 50% of the same words in order to be considered for
## the matching phase

# %%
output_pairs_ws = ssj.jaccard_join(MSD_TABLE, MBRAINZ_TABLE, 'ID', 'ID', 'title', 'title', ws, 0.5, 
                                l_out_attrs=['title','artist','year'], r_out_attrs=['title','artist','year'])
# Out:
# 0%                          100%
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:01:18

# %%
## The length of this list will be the solution space that will be 
## searched in the matching phase
len(output_pairs_ws)
# Out:
# 385009

# %%
## We will rerun the blocking phase with a new threshold of 0.7 
## in attempts to reduce space even further
output_pairs_ws_7 = ssj.jaccard_join(MSD_TABLE, MBRAINZ_TABLE, 'ID', 'ID', 'title', 'title', ws, 0.7, 
                                l_out_attrs=['title'], r_out_attrs=['title'])
# Out:
# 0%                          100%
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:00:08

# %%
len(output_pairs_ws_7)
# Out:
# 51322

# %%
## This is the most reduced thus far

# %%
## We will repeat the Jacaard score using the qgram technique
## this time. 
output_pairs_js_5 = ssj.jaccard_join(MSD_TABLE, MBRAINZ_TABLE, 'ID', 'ID', 'title', 'title', gram3, 0.5, 
                                l_out_attrs=['title'], r_out_attrs=['title'])
# Out:
# 0%                          100%
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:10:30

# %%
len(output_pairs_js_5)
# Out:
# 124953

# %%
output_pairs_js_7 = ssj.jaccard_join(MSD_TABLE, MBRAINZ_TABLE, 'ID', 'ID', 'title', 'title', gram3, 0.7, 
                                l_out_attrs=['title','artist','year'], r_out_attrs=['title','artist','year'])

# %%
len(output_pairs_js_7)

# %%
## We will print out all of the possible solution sets found by 
## blocking
print("Jacaard with whitespace tokenization and threshold of 0.5: ", len(output_pairs_ws))
print("Jacaard with whitespace tokenization and threshold of 0.7: ", len(output_pairs_ws_7))
print("Jacaard with 3-gram tokenization and threshold of 0.5: ", len(output_pairs_js_5))
print("Jacaard with 3-gram tokenization and threshold of 0.7: ", len(output_pairs_js_7))

# %%
## Jacaard score using 3-gram and a threshold of 0.7 reduces the 
## possible solution space the most. We will use this table for 
## matching.

# %%
output_pairs_js_7

# %%
em.to_csv_metadata(output_pairs_js_7, '../../csv/candidate_set.csv')

# %%
dbg = em.debug_blocker(output_pairs_js_7, MSD_TABLE, MBRAINZ_TABLE)
