# %%
#### GET A SAMPLE BABY #####

# %%
#import random
import pandas
import os

# %%
#### select your random seed #####

#### Currently Running: 303 
#### Have Run: 303, 200

# %%
seed = input("Select your random seed: ")
# Out:
# Select your random seed: 303

# %%
### read CSV and SAMPLE 400 ####

# %%
candidates = pandas.read_csv(os.path.join( os.getcwd(), "../../csv", "candidates_final2.csv"))
sample = candidates.sample(n=400, random_state=int(seed), replace=False)

# %%
### Segment Sample ###
sample_1 = sample[:50]
sample_2 = sample[50:100]
sample_3 = sample[100:150]
sample_4 = sample[150:200]
sample_5 = sample[200:250]
sample_6 = sample[250:300]
sample_7 = sample[300:350]
sample_8 = sample[350:400]

path = "../../csv/sample_label/"+seed+"/"
if not os.path.exists(path):
    os.makedirs(path)

sample_1.to_csv(path+"sample2_1_"+seed+".csv")
sample_2.to_csv(path+"sample2_2_"+seed+".csv")
sample_3.to_csv(path+"sample2_3_"+seed+".csv")
sample_4.to_csv(path+"sample2_4_"+seed+".csv")
sample_5.to_csv(path+"sample2_5_"+seed+".csv")
sample_6.to_csv(path+"sample2_6_"+seed+".csv")
sample_7.to_csv(path+"sample2_7_"+seed+".csv")
sample_8.to_csv(path+"sample2_8_"+seed+".csv")


sample_1
# Out:
#           id ltable_ID rtable_ID                              ltable_title  \
# 3954    3954   b530662    a10042                                  Evidence
# 8297    8297   b337425    a19494                           Do You Remember
# 5535    5535   b590494    a14315                       Night Boat To Cairo
# 3320    3320   b478767     a8262        Jump That Rock (Whatever You Want)
# 8914    8914   b791776    a20761                                 Flashback
# 7705    7705    b99503    a18428                                 Sail Away
# 10500  10500   b102786    a24409                              Resurrection
# 8178    8178   b716663    a19267                                Growing Up
# 12314  12314   b691548    a28919                          Grandpa's Spells
# 12157  12157   b707441    a28398                          Never Let You Go
# 12015  12015   b314346    a28061                                   Freedom
# ...
